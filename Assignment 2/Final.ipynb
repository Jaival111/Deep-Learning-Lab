# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD, Adam
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
x_train_cnn = x_train[..., None]
x_test_cnn = x_test[..., None]

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
model = models.Sequential([
    layers.Input(shape=(28, 28, 1)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.1),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

history = model.fit(
    x_train_cnn, y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.1
)

accuracy = model.evaluate(x_test_cnn, y_test, verbose=0)[1]
history_ = history
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 422/422 [==============================] - 13s 8ms/step - loss: 0.1682 - accuracy: 0.9484 - val_loss: 0.0516 - val_accuracy: 0.9862
# Epoch 2/20
# 422/422 [==============================] - 4s 8ms/step - loss: 0.0479 - accuracy: 0.9853 - val_loss: 0.0413 - val_accuracy: 0.9870
# Epoch 3/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0305 - accuracy: 0.9903 - val_loss: 0.0356 - val_accuracy: 0.9908
# Epoch 4/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0190 - accuracy: 0.9941 - val_loss: 0.0346 - val_accuracy: 0.9903
# Epoch 5/20
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.0388 - val_accuracy: 0.9908
# Epoch 6/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0469 - val_accuracy: 0.9898
# Epoch 7/20
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0386 - val_accuracy: 0.9907
# Epoch 8/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0564 - val_accuracy: 0.9867
# Epoch 9/20
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0587 - val_accuracy: 0.9888
# Epoch 10/20
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0464 - val_accuracy: 0.9908
# Epoch 11/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0490 - val_accuracy: 0.9895
# Epoch 12/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0444 - val_accuracy: 0.9910
# Epoch 13/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0422 - val_accuracy: 0.9925
# Epoch 14/20
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0457 - val_accuracy: 0.9903
# Epoch 15/20
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0484 - val_accuracy: 0.9895
# Epoch 16/20
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.0534 - val_accuracy: 0.9897
# Epoch 17/20
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0482 - val_accuracy: 0.9922
# Epoch 18/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0535 - val_accuracy: 0.9907
# Epoch 19/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0428 - val_accuracy: 0.9923
# Epoch 20/20
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0416 - val_accuracy: 0.9930

# %%
plt.figure()
plt.plot(history_.history['accuracy'], label='accuracy')
plt.plot(history_.history['loss'], label='loss')
plt.plot(history_.history['val_accuracy'], label='val_accuracy')

plt.xlabel('Epochs')
plt.title('CNN Training without BN and Drop Out')
plt.legend()
plt.show()
